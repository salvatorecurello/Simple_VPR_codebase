# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %%time
# move into your mounted GDrive filesystem
# %cd /content/drive/MyDrive/Project/datasets

# unzip the datasets to /content, so you don't risk going over the GDrive storage limit
# this can take a few minutes
# !unzip -q gsv_xs.zip -d /content
# !unzip -q tokyo_xs.zip -d /content
# !unzip -q sf_xs.zip -d /content
# Out:
# /content/drive/MyDrive/Project/datasets
# CPU times: user 1.05 s, sys: 138 ms, total: 1.19 s
# Wall time: 2min 20s

# %%
# %cd /content/drive/MyDrive/Project/Simple_VPR_codebase
# Out:
# /content/drive/MyDrive/Project/Simple_VPR_codebase

# %%
import os
folder_path = '/content/gsv_xs/train/barcelona'

if os.path.exists(folder_path) and os.path.isdir(folder_path):
    # Get a list of filenames in the folder
    filenames = os.listdir(folder_path)

    # You can optionally filter the list to only include files (not directories)
    # filenames = [f for f in filenames if os.path.isfile(os.path.join(folder_path, f))]

# %%
filenames[0:5]
# Out:
# ['@0431006.30@4583574.14@31@T@041.40074@0002.17462@jyMsZEN8-BlPJQCeABVvCg@@594@@@@201410@1605_Barcelona@.jpg',
#  '@0429037.73@4579465.48@31@T@041.36357@0002.15155@3AiR5Rwe1EXbQMn4tPcbRQ@@469@@@@201410@303_Barcelona@.jpg',
#  '@0425919.19@4581289.56@31@T@041.37971@0002.11405@xvDZwQIaS__0tG80V8IDpA@@547@@@@201806@845_Barcelona@.jpg',
#  '@0430985.88@4581082.91@31@T@041.37830@0002.17466@ZlbJDIanaOtzZIn9cmOorg@@532@@@@201401@826_Barcelona@.jpg',
#  '@0430994.49@4583047.97@31@T@041.39600@0002.17454@uTyybGR1ZyMEoBzC9RgZUw@@396@@@@201503@1441_Barcelona@.jpg']

# %%
latitude = []
longitude = []
for filename in filenames:
  parts = filename.split("@")
  latitude.append(parts[5][1:])
  longitude.append(parts[6][3:])

# %%
len(latitude)
# Out:
# 15894

# %%
len(longitude)
# Out:
# 15894

# %%
import pandas as pd
d = {'Latitudes': latitude, 'Longitudes': longitude}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#       Latitudes Longitudes
# 0      41.40074    2.17462
# 1      41.36357    2.15155
# 2      41.37971    2.11405
# 3      41.37830    2.17466
# 4      41.39600    2.17454
# ...         ...        ...
# 15889  41.36698    2.11228
# 15890  41.38601    2.15345
# 15891  41.39612    2.16788
# 15892  41.36554    2.11855
# 15893  41.38633    2.15075
#
# [15894 rows x 2 columns]

# %%
# df.to_excel("/content/drive/MyDrive/Project/Simple_VPR_codebase/utils/barcelona_coordinates.xlsx", index=False)

# %%
# df.to_csv("/content/drive/MyDrive/Project/Simple_VPR_codebase/utils/barcelona_coordinates.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Project/Simple_VPR_codebase/utils/barcelona_coordinates.csv")

# %%
df = df.astype({'Latitudes':'float','Longitudes':'float'})

# %%
import plotly.express as px

fig = px.scatter_mapbox(df, lat="Latitudes", lon="Longitudes", color_discrete_sequence=["fuchsia"], zoom=13, height=1000)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
